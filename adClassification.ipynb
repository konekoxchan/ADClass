        fullList.append(trainPath + "\\" + folder + "\\" + img)         

print(fullList[1500])
        
for im, n in zip(fullList, list):
    if n==150:
        print(im)
    if "Non" in im:
        trainYList[n][0] = 1
    elif "Very" in im:
        trainYList[n][1] = 1
    elif "Mild" in im:
        trainYList[n][2] = 1
    elif "Moderate" in im:
        trainYList[n][3] = 1
    im = cv2.imread(im)
    im = cv2.resize(im, (200, 200))
    tempXList[n] = im
    l0, l1, l2 = cv2.split(tempXList[n])
    for x in range(0, 200):
        tempL = (l0 + l1 + l2)/3
        trainXList[n] = tempL
        
print(trainYList[150])
plt.imshow(trainXList[150])
# Out:
# MildDemented
# ModerateDemented
# NonDemented
# VeryMildDemented
# C:\Users\ebudy\ADDataset\adSet\train\NonDemented\nonDem1656.jpg
# C:\Users\ebudy\ADDataset\adSet\train\VeryMildDemented\verymildDem540.jpg
# [0 1 0 0]

# %%
temptestList = np.zeros((1279, imgH, imgW, 3), dtype=np.uint8)
testYList = np.zeros((1279, 4), dtype=int)
fullList = []

for folder, n in zip(os.listdir(testPath), range(1279)):
    print(folder)
    for img in os.listdir(testPath + "\\" + folder):
        fullList.append(testPath + "\\" + folder + "\\" + img)
        
for im, n in zip(fullList, range(1279)):
    if "Non" in im:
        testYList[n][0] = 1
    elif "Very" in im:
        testYList[n][1] = 1
    elif "Mild" in im:
        testYList[n][2] = 1
    elif "Moderate" in im:
        testYList[n][3] = 1
    im = cv2.imread(im)
    im = cv2.resize(im, (200, 200))
    temptestList[n] = im
    l0, l1, l2 = cv2.split(temptestList[n])
    for x in range(0, 200):
        tempL = (l0 + l1 + l2)/3
        testList[n] = tempL
        
print(testYList[150])
plt.imshow(testList[150])
# Out:
# MildDemented
# ModerateDemented
# NonDemented
# VeryMildDemented
# [0 0 1 0]

# %%
XList = np.zeros((5121, 40000), dtype=np.uint8)
testXList = np.zeros((1279, 40000), dtype=np.uint8)

for item, n in zip(trainXList, list):
    XList[n] = item.flatten()
    XList[n] = XList[n]/255
    
for item, n in zip(testList, range(1279)):
    testXList[n] = item.flatten()
    testXList[n] = testXList[n]/255

# %%
kerasMod = tf.keras.Sequential()
kerasMod.add(Dense(16, input_shape=(40000, ), activation='relu'))
kerasMod.add(Dense(16, activation='relu'))
kerasMod.add(Dense(4, activation='sigmoid'))
kerasMod.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                640016
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 640,356
# Trainable params: 640,356
# Non-trainable params: 0
# _________________________________________________________________

# %%
kerasMod.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
results = kerasMod.fit(XList, trainYList, batch_size=100, epochs=30)
# Out:
# Epoch 1/30
# 52/52 [==============================] - 6s 58ms/step - loss: 1.3696 - accuracy: 0.4979
# Epoch 2/30
# 52/52 [==============================] - 3s 54ms/step - loss: 1.3373 - accuracy: 0.4999
# Epoch 3/30
# 52/52 [==============================] - 2s 35ms/step - loss: 1.3087 - accuracy: 0.4999
# Epoch 4/30
# 52/52 [==============================] - 2s 35ms/step - loss: 1.2832 - accuracy: 0.4999
# Epoch 5/30
# 52/52 [==============================] - 2s 35ms/step - loss: 1.2604 - accuracy: 0.4999
# Epoch 6/30
# 52/52 [==============================] - 2s 35ms/step - loss: 1.2402 - accuracy: 0.4999
# Epoch 7/30
# 52/52 [==============================] - 2s 34ms/step - loss: 1.2221 - accuracy: 0.4999
# Epoch 8/30
# 52/52 [==============================] - 2s 32ms/step - loss: 1.2060 - accuracy: 0.4999
# Epoch 9/30
# 52/52 [==============================] - 2s 37ms/step - loss: 1.1916 - accuracy: 0.4999
# Epoch 10/30
# 52/52 [==============================] - 2s 39ms/step - loss: 1.1786 - accuracy: 0.4999
# Epoch 11/30
# 52/52 [==============================] - 2s 34ms/step - loss: 1.1670 - accuracy: 0.4999
# Epoch 12/30
# 52/52 [==============================] - 2s 33ms/step - loss: 1.1566 - accuracy: 0.4999
# Epoch 13/30
# 52/52 [==============================] - 2s 36ms/step - loss: 1.1473 - accuracy: 0.4999
# Epoch 14/30
# 52/52 [==============================] - 2s 36ms/step - loss: 1.1390 - accuracy: 0.4999
# Epoch 15/30
# 52/52 [==============================] - 2s 35ms/step - loss: 1.1315 - accuracy: 0.4999
# Epoch 16/30
# 52/52 [==============================] - 2s 35ms/step - loss: 1.1246 - accuracy: 0.4999
# Epoch 17/30
# 52/52 [==============================] - 2s 29ms/step - loss: 1.1185 - accuracy: 0.4999
# Epoch 18/30
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1129 - accuracy: 0.4999
# Epoch 19/30
# 52/52 [==============================] - 2s 29ms/step - loss: 1.1079 - accuracy: 0.4999
# Epoch 20/30
# 52/52 [==============================] - 2s 35ms/step - loss: 1.1032 - accuracy: 0.4999
# Epoch 21/30
# 52/52 [==============================] - 2s 34ms/step - loss: 1.0989 - accuracy: 0.4999
# Epoch 22/30
# 52/52 [==============================] - 2s 33ms/step - loss: 1.0950 - accuracy: 0.4999
# Epoch 23/30
# 52/52 [==============================] - 2s 30ms/step - loss: 1.0914 - accuracy: 0.4999
# Epoch 24/30
# 52/52 [==============================] - 1s 27ms/step - loss: 1.0881 - accuracy: 0.4999
# Epoch 25/30
# 52/52 [==============================] - 2s 34ms/step - loss: 1.0850 - accuracy: 0.4999
# Epoch 26/30
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0821 - accuracy: 0.4999
# Epoch 27/30
# 52/52 [==============================] - 1s 23ms/step - loss: 1.0795 - accuracy: 0.4999
# Epoch 28/30
# 52/52 [==============================] - 1s 25ms/step - loss: 1.0770 - accuracy: 0.4999
# Epoch 29/30
# 52/52 [==============================] - 2s 35ms/step - loss: 1.0747 - accuracy: 0.4999
# Epoch 30/30
# 52/52 [==============================] - 2s 39ms/step - loss: 1.0725 - accuracy: 0.4999

# %%
preds_train = kerasMod.predict(XList, verbose=1)
preds_val = kerasMod.predict(XList, verbose=1)
preds_test = kerasMod.predict(testXList, verbose=1)

misclassified=np.where(testYList!=preds_test)
print(misclassified)
print(len(misclassified[0]))
# Out:
# 161/161 [==============================] - 1s 7ms/step
# 161/161 [==============================] - 1s 6ms/step
# 40/40 [==============================] - 0s 6ms/step
# (array([   0,    0,    0, ..., 1278, 1278, 1278], dtype=int64), array([0, 1, 2, ..., 1, 2, 3], dtype=int64))
# 5116
